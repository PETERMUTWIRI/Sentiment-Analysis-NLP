# %% [markdown]
# # Sentiment Analysis with Hugging Face

# %% [markdown]
# Hugging Face is an open-source and platform provider of machine learning technologies. You can use install their package to access some interesting pre-built models to use them directly or to fine-tune (retrain it on your dataset leveraging the prior knowledge coming with the first training), then host your trained models on the platform, so that you may use them later on other devices and apps.
#
# Please, go to the website and sign-in to access all the features of the platform.
#
# Read more about Text classification with Hugging Face
#
# The Hugging face models are Deep Learning based, so will need a lot of computational GPU power to train them. Please use Colab to do it, or your other GPU cloud provider, or a local machine having NVIDIA GPU.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# In the previous EDA/Clean Data notebook, the NLP dataset was cleaned and there was an exploration of the dataset. Models will be created from the data. Two models, namely,RoBerTa and DistillBeRT from HuggingFace will be fine tuned.

# %% [markdown]
# # Installations

# %%
# %%capture
# !pip install transformers
# !pip install accelerate -U
# !pip install datasets
# !pip install huggingface_hub

# %% [markdown]
# ### Dependencies Importations

# %%
##for handling path of my datasets
import os
from google.colab import drive

##for data handling:

import pandas as pd
import numpy as np

from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
from transformers import TrainingArguments
from scipy.special import softmax
from torch import nn
import torch
from transformers import Trainer

##modelling:

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import transformers
from transformers import pipeline
from datasets import load_dataset
import nltk
nltk.download('punkt')
##others
import warnings
warnings.filterwarnings("ignore")
import os
os.environ["WANDB_DISABLED"] = "true"
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# **Importing dataset from Google Drive**

# %%
data_path=  "/content/drive/MyDrive/Colab Notebooks/NLP/Transformed_copy.csv"

# %%
# read data
data= pd.read_csv(data_path)

# %%
data.head()
# Out:
#    Unnamed: 0                                         safe_tweet  label  \
# 0           0                   amp big homie meanboy stegman st    0.0
# 1           1  im thinking devoting career proving autism isn...    1.0
# 2           2                           vaccines vaccinate child   -1.0
# 3           3  mean immunize kid something wont secretly kill...   -1.0
# 4           4  thanks catch performing la nuit nyc st ave sho...    0.0
#
#    agreement
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0

# %%
#Check for null values

data.isna().sum()
# Out:
# Unnamed: 0     0
# safe_tweet    29
# label          0
# agreement      0
# dtype: int64

# %%
data[data["safe_tweet"].isnull()]
# Out:
#       Unnamed: 0 safe_tweet  label  agreement
# 444          444        NaN    0.0   1.000000
# 1523        1523        NaN    0.0   1.000000
# 2155        2155        NaN    0.0   1.000000
# 2515        2515        NaN    0.0   1.000000
# 3062        3062        NaN    0.0   0.666667
# 3204        3204        NaN    0.0   1.000000
# 3819        3819        NaN    1.0   0.666667
# 4631        4631        NaN    0.0   1.000000
# 4638        4638        NaN    0.0   1.000000
# 4770        4770        NaN    0.0   1.000000
# 5423        5425        NaN    0.0   1.000000
# 5441        5443        NaN    0.0   1.000000
# 5577        5579        NaN    0.0   1.000000
# 5989        5991        NaN    0.0   1.000000
# 6226        6228        NaN    0.0   0.666667
# 6451        6453        NaN    0.0   0.666667
# 6494        6496        NaN   -1.0   0.666667
# 6507        6509        NaN   -1.0   0.333333
# 7028        7030        NaN    0.0   1.000000
# 7208        7210        NaN    0.0   1.000000
# 7214        7216        NaN    1.0   0.666667
# 7471        7473        NaN    1.0   0.666667
# 7863        7865        NaN   -1.0   1.000000
# 7921        7923        NaN    0.0   1.000000
# 8249        8251        NaN    1.0   1.000000
# 8566        8568        NaN    0.0   1.000000
# 8846        8848        NaN    0.0   1.000000
# 8936        8938        NaN    0.0   0.666667
# 9549        9551        NaN    0.0   1.000000

# %%
##drop Unnamed column and missing values to facilitate analysis
data= data.dropna()
data= data.drop("Unnamed: 0", axis=1)

# %%
data
# Out:
#                                              safe_tweet  label  agreement
# 0                      amp big homie meanboy stegman st    0.0   1.000000
# 1     im thinking devoting career proving autism isn...    1.0   1.000000
# 2                              vaccines vaccinate child   -1.0   1.000000
# 3     mean immunize kid something wont secretly kill...   -1.0   1.000000
# 4     thanks catch performing la nuit nyc st ave sho...    0.0   1.000000
# 5     nearly year old study mental health studies va...    1.0   0.666667
# 6              study kids finds link mmr vaccine autism    1.0   0.666667
# 7                            psa vaccinate fucking kids    1.0   1.000000
# 8        coughing extra shuttle everyone thinks measles    1.0   0.666667
# 9     aids vaccine created oregon health amp science...    1.0   0.666667
# 10    point text butwbon jovi cover playin alibis ho...    0.0   1.000000
# 11    prediction vaccine exemption arizona will end ...    0.0   0.666667
# 12    getting vaccines cheryl southern nevada health...    1.0   1.000000
# 13                                 mug noche mad hatter    0.0   1.000000
# 14    got influenza vaccine purdue university studen...    1.0   0.666667
# 15    sb enroll meningococcal diseasepupils immunize...    0.0   0.666667
# 16    increasing number parents skip vaccinations ch...    0.0   1.000000
# 17           thank standing ca parents children support    1.0   1.000000
# 18    dude idc disney land measles means shorter lin...    0.0   1.000000
# 19    beeftalk start calf vaccinations now via good ...    1.0   1.000000
# 20              dont care says probably kids vaccinated    1.0   1.000000
# 21    small study shows pts lupus shingles vaccine s...    1.0   0.666667
# 22    cdc measles epidemic poses travel risks usatly...    0.0   1.000000
# 23    every time see vaccinate debate wonder one sid...    1.0   1.000000
# 24    lied hid data black boys uncreased risk develo...   -1.0   1.000000
# 25                              vaccines causing autism   -1.0   1.000000
# 26    rarely see arguments vaccination actually big ...    0.0   0.666667
# 27    im obsessed w ebola following outbreak worlds ...    1.0   0.666667
# 28    joshthenewt suck game haha well people say don...    0.0   1.000000
# 29    dont shake hand pocahontas thats probably meas...    0.0   0.666667
# 30    yes im part public health im part nature feed ...    1.0   1.000000
# 31    new studies show vaccines associated autism ne...    1.0   1.000000
# 32    repetitive less shocked increase asd even gene...    1.0   1.000000
# 33    glad got vaccinated health alert case meningit...    1.0   1.000000
# 34                                     look got measles    0.0   0.666667
# 35     defense vaccines harmful american life unhealthy   -1.0   0.333333
# 36    hello ranked reset probably bad placements mmr...    0.0   1.000000
# 37    amid measles outbreak vaccines teachers arent ...    0.0   0.666667
# 38                                       measles threat    0.0   0.666667
# 39    improve mood energy immunity cardio health kit...    0.0   1.000000
# 40    mt new bill end exemptions personal religious via    0.0   1.000000
# 41                       autism immunizations vaccinate    0.0   0.666667
# 42    bart riders warned measles infection contagiou...    0.0   1.000000
# 43    us cases hit year high far year cases measles ...    0.0   0.666667
# 44    pull myxx nightlife stint t performing live ho...    0.0   1.000000
# 45    cdc eyeing bird flu vaccine humans though risk...    0.0   0.666667
# 46    involved fight preventable diseases tenure tra...    1.0   0.666667
# 47                              im vaccinating kids lol   -1.0   1.000000
# 48    alleged victim reviewing immunity paperwork re...    0.0   1.000000
# 49    thanksuser crystal clear lack evidence linking...    1.0   0.666667
# 50                 giving dvds vaccinating children bad    0.0   0.666667
# 51            hey nowuser mixmasterrods upstairs lounge    0.0   1.000000
# 52    seriously dont want child antivaccination move...    1.0   1.000000
# 53    epidemic enterovirus mumps now measles drug re...    0.0   1.000000
# 54    said wasnt gone shit lol looked proved wrong baby    0.0   1.000000
# 55    flu shots school boost vaccination rates offer...    0.0   0.666667
# 56    marin county school board sides young leukemia...    0.0   0.666667
# 57             still running niggas til death dibiasimb    0.0   1.000000
# 58    yeah ill stick regular vaccines oh wait gives ...   -1.0   0.666667
# 59    antivaccine people want control people fear we...    1.0   1.000000
# 60              important measles update says working w    1.0   1.000000
# 61    dont think will understand peoples reasons get...    1.0   0.666667
# 62    cia vaccination campaigns spy ops via harm pro...   -1.0   0.666667
# 63    measles outbreak prompts vaccination debate po...    0.0   1.000000
# 64    people need children vaccinated bad diseases c...    1.0   1.000000
# 65       vaccine brain damage cover implodes discussing   -1.0   1.000000
# 66                            vaccines childrens clinic    0.0   0.666667
# 67      know infected measles airborne transmission wtf    0.0   1.000000
# 68    access fitchburg school limited amid measles s...    0.0   1.000000
# 69    deadly kids allergies joke deadly child measle...    1.0   1.000000
# 70                                              measles    0.0   0.666667
# 71    topic makes scared bring kids modern society t...    1.0   1.000000
# 72     stop blaming first now diseasesbrought ancestors    1.0   0.666667
# 73                                 already cure measles    0.0   1.000000
# 74                 cant attend school unless vaccinated    0.0   1.000000
# 75      dont vaccinate children shitty parent end story    1.0   1.000000
# 76    citizen kingdom god assignment diplomatic immu...    0.0   1.000000
# 77    top colorado doctor says adults worried measle...    1.0   1.000000
# 78       nah idiot someone doesnt allow kids vaccinated    1.0   1.000000
# 79    kids need vaccinations late thcentury maps sho...    1.0   1.000000
# 80          measles fears spread nj amid suspected case    0.0   1.000000
# 81    baby vaccination day shes getting measles one ...    1.0   1.000000
# 82            loving measles poster making spirit today    0.0   1.000000
# 83    baseball coach santa monica high contracts mea...    0.0   1.000000
# 84    im sick hearing people vaccinating children si...    1.0   1.000000
# 85     one risky childrena vaccination going school car    0.0   0.666667
# 86                       odds kid measles uses lab room    0.0   1.000000
# 87    parents refuse kids immunized charged reckless...    1.0   1.000000
# 88           rt vaccinations measles medicaid expansion    0.0   1.000000
# 89    centers disease control years flu vaccine does...   -1.0   0.666667
# 90    ty fought hard vaccinate kids yrs peoples judg...   -1.0   0.666667
# 91    vaccinate people tarrant county cases five den...    1.0   0.666667
# 92    hb new providing health insurance coverage imm...    0.0   0.666667
# 93    a new revises codifies schedule childhood lead...    0.0   0.666667
# 94    fridays immunity challenge walking backwards s...    0.0   0.666667
# 146   gates foundation pledges billion immunize poor...    1.0   0.666667
# 147   reading fb comments measles articles great ent...    0.0   1.000000
# 148   eric holder forcing send babies start school i...    1.0   0.666667
# 149   aids n qhpv vaccine reduces risk costs among o...    1.0   0.666667
# 150   isnt news talking measles wiped came back cuz ...    1.0   0.666667
# 151   dont flu vaccine know safe im letting rest sch...   -1.0   1.000000
# 152   mountain glorious day cherry blossoms lunch w ...    0.0   0.666667
# 153   hmcheck wounds may infection vaccines arent da...    0.0   0.666667
# 154   partial agreement measles cases result law lar...    0.0   1.000000
# 155             theyre heeeere dc confirms case measles    0.0   0.666667
# 156                                      vaccinate kids    1.0   1.000000
# 157   nice discussion vaccines kidney transplant rec...    0.0   1.000000
# 158   last one vaccinate damn children swear god hea...    1.0   1.000000
# 159   wont say politically correct vaccinate kids po...    1.0   1.000000
# 160                     omg day got drunk af pm wow mmr    0.0   1.000000
# 161   gave adorable little asian kid piece chalk dra...    0.0   0.666667
# 162   didnt vaccinatedampwe survived smallpox measle...   -1.0   0.666667
# 163                                njoying moments life    0.0   1.000000
# 164   people vaccinate kids outbreaks happen people ...    1.0   1.000000
# 165   vaccinated kids yesterday rt flurelated pediat...    1.0   1.000000
# 166                measles outbreak vaccinate vaccinate    0.0   0.666667
# 167                stick science dont want measles back    1.0   1.000000
# 168   wonder many measles cases walking around heres...    0.0   1.000000
# 169   people vaccinated truth parroting words contex...    0.0   0.666667
# 170                   double blind studies showing work   -1.0   1.000000
# 171                                   yo mugs nuff said    0.0   1.000000
# 172   measles cases ventura county prompt vaccinatio...    1.0   0.666667
# 173   will never understand parents dont kids vaccin...    1.0   1.000000
# 174                        come pray mmr marian gardens    0.0   1.000000
# 175                 watched mmr truck hit cat bastereds    0.0   1.000000
# 176          dont know causes autism know vaccines dont    1.0   1.000000
# 177      ask bumps already shingles chicken pox measles    0.0   1.000000
# 178          doubt immunity will open lips truth lerner    0.0   1.000000
# 179   injuries amp death heres article many simple g...   -1.0   1.000000
# 180   whats increase reported measles tb past five y...    0.0   1.000000
# 181   babies die sickened bad vaccines south mexico ...    0.0   0.666667
# 182                                    mmr x db deigner    0.0   1.000000
# 183   say brooklyn biggie mogul presents franchise l...    0.0   1.000000
# 184   measles cases year high parents failing childr...    1.0   0.666667
# 185   worried outbreak local doctors answer question...    0.0   1.000000
# 186    take toxin vaccine youll cancer autism wont hugs   -1.0   1.000000
# 187   ya ready con pala caravana de texas saludos y ...    0.0   1.000000
# 188   pissed blood test see measles vaccine still go...    1.0   1.000000
# 189   taxpayer money wasted cdc canada comes vaccine...    0.0   1.000000
# 190                     mmr meets bliss thursday august    0.0   1.000000
# 191   cant brother awful reaction friends child deve...   -1.0   1.000000
# 192                s new department healthimmunizations    0.0   0.666667
# 193   important rt measles cases california outbreak...    1.0   0.666667
# 194   cat vomit toddler tantrums kindergarten party ...    0.0   1.000000
# 195      think day measles child concernedi now yrs old    0.0   1.000000
# 196   aids vaccine created oregon health amp science...    1.0   1.000000
# 197    parents warned vaccinating kids may turn gay via   -1.0   0.333333
# 198   need ask measles outbreak illegalswhere fit ep...    0.0   1.000000
# 199   take kids playground amp measles another paren...    1.0   1.000000
# 200   sb enroll providing immunity civil criminal li...    0.0   0.666667
# 201   gov christie parents choice whether vaccinate ...    0.0   0.666667
# 202              love measles go measles take goodnight    0.0   1.000000
# 203   father boy leukemia asks california school off...    1.0   0.666667
# 204   yes ill take vaccines amp please keep ur unvac...    1.0   0.666667
# 205                           simple vaccinate kids end    1.0   1.000000
# 206   new measles cases confirmed san mateo marin co...    0.0   1.000000
# 207   dr nicole bates imagine global health policy s...    1.0   1.000000
# 208   yas argument medically necessary vaccinate chi...    1.0   0.666667
# 209   pete carroll blew super bowl going now im goin...    0.0   1.000000
# 210                    outbreak spreads lower east side    0.0   1.000000
# 211   california lawmakers aim limit vaccine exemptions    1.0   1.000000
# 212   full disclosure measles kids whereabouts past ...    0.0   0.666667
# 213   fuckn ball wit n whole mmr team hate leave got...    0.0   1.000000
# 214          survived amp now lifetime natural immunity    0.0   1.000000
# 215   measles outbreak az monitored locally health w...    0.0   0.666667
# 216   autism family losing home click donate via vac...    0.0   0.666667
# 217   taylees getting second round immunizations tod...    1.0   0.666667
# 218   vaccines contain aluminum conditions associate...   -1.0   1.000000
# 219   jenny mccarthy gets crucified twitter antivacc...    1.0   0.666667
# 220           parts africa people vaccinated measles us    0.0   0.666667
# 221   vaccinations work safe choice herd immunity fa...    1.0   1.000000
# 222   girls first casserole inside ohh turn stuffed ...    0.0   1.000000
# 223                    im mmr station mount pleasant mi    0.0   1.000000
# 224   remedies available citizens harmed due site ha...    0.0   1.000000
# 225    childrens museum houston offer free vaccinations    1.0   0.666667
# 226   case measles suspected baltimore county child ...    0.0   1.000000
# 227   apparently nasal spray live culture flu vaccin...   -1.0   0.333333
# 228   something super bowl katy perry vaccinations k...    0.0   1.000000
# 229   scientist recalls outbreak angelenos caught me...    0.0   1.000000
# 230   im emos death vaccines red river st e th st au...    0.0   1.000000
# 231   watch volunteers risking lives vaccinate child...    1.0   1.000000
# 232   im totally going disneyland ive measles vaccin...    1.0   1.000000
# 233   jesus didnt vaccinate neither will kids dumbes...    1.0   1.000000
# 234                           vaccinations hope measles    1.0   1.000000
# 235   im diabetic heart patient need take measles va...    0.0   0.666667
# 236   cdc coverage national immunization survey info...    0.0   1.000000
# 237    poor baby getting vaccines today home sweet home    1.0   1.000000
# 238   flu vaccine small amounts mercury bad build im...   -1.0   0.666667
# 239   vaccinations must requirement many infants vac...    1.0   1.000000
# 240        vaccine safe effective amp kids need booster    1.0   1.000000
# 241   amnews new forms vaccines offer promising resu...    0.0   0.666667
# 242   troubling hearing parents wont vaccinate children    1.0   1.000000
# 243   everything home tuesday marjais meet w tyraton...    0.0   1.000000
# 244   seriously people kids vaccinated will never un...    1.0   1.000000
# 245      issue important vaccinate children takes stage    1.0   1.000000
# 246         finally getting immunization records school    1.0   0.666667
# 247   parents didnt kids measles vaccination take ho...    1.0   0.666667
# 248   nothing pisses young mothers know nothing micr...    1.0   1.000000
# 249   parents vaccinating kids feel free walk edge e...    1.0   1.000000
# 250             things know san diegos measles outbreak    0.0   1.000000
# 251   measles outbreak bc ignorant parents refuse va...    1.0   1.000000
# 252   today blocked autism parent support group nj v...    0.0   0.666667
# 253                 bottom line vaccinate children guys    1.0   1.000000
# 254   grandsons pediatrician acknowledged vaccine in...   -1.0   1.000000
# 255   say misting fly neighborhoodsamp mist vaccinat...    0.0   0.666667
# 256   dont vaccinate kids youre uneducated dumbass p...    1.0   1.000000
# 257   passed chex exams got vaccinated amp tested ca...    1.0   1.000000
# 258   allow interrupt rq vaccines way shape form rel...    1.0   1.000000
# 259   sb passed meningococcal diseasepupils immunize...    0.0   0.666667
# 260                hah ha ha fucking vaccinate children    1.0   0.666667
# 261             miners fight field pregame learned fast    0.0   1.000000
# 262   measles outbreak centered disneyland may decla...    0.0   1.000000
# 263   stuffconz fear grows outbreak medical authorit...    1.0   0.666667
# 264   yup sky still blue icymi vaccines clearedagain...    1.0   1.000000
# 265                           im mmr station weidman mi    0.0   1.000000
# 266   people disneyland measles outbreak unvaccinate...   -1.0   0.666667
# 267        un stops syria vaccine campaign children die   -1.0   0.666667
# 268         jijijiji mmr acabo de ver tus tweets apenas    0.0   1.000000
# 269   tarrant county confirms another measles case t...    0.0   1.000000
# 270   flu shots never proven protect getting flu vac...   -1.0   0.666667
# 271   dont act surprised gtyikes thousands bart comm...    1.0   0.666667
# 272        rtuser study finds link immunizations autism    1.0   1.000000
# 273   epa knows ppm fluoride killed million babies l...   -1.0   1.000000
# 274   reminder work health rightexercisevaccines pro...    1.0   0.666667
# 275   jim think worthy opponent dwight correct unles...    0.0   1.000000
# 276                                  maybe woke measles    0.0   1.000000
# 277   one mangeridden raccoon apparently w diseases ...    0.0   1.000000
# 278   one countries children missed vaccinations tet...    1.0   1.000000
# 279                now got measles outbreak disney land    0.0   1.000000
# 280   million pledges vaccinate world kids britain n...    1.0   0.666667
# 281   actual debate vaccinating kids nobrainer calli...    1.0   1.000000
# 282                               measles mumps novella    0.0   1.000000
# 283   yrold son autism amp absolutely vaccinatedhis ...    1.0   1.000000
# 284                               vaccines cause autism    1.0   0.666667
# 285   someone got measles vaccine chance recurring p...   -1.0   0.333333
# 286   vaccines important health need affordable bett...    1.0   1.000000
# 287   previously vaccinated peoples antibodies low n...    0.0   0.666667
# 288   health district offers nocost immunizations un...    1.0   0.666667
# 289   saddest part dont keep crazy son autistic fhea...    1.0   0.666667
# 290   power truth rally years later trace amounts do...   -1.0   0.666667
# 291   vaccines give children opportunity live full p...    1.0   1.000000
# 292                          cancer vaccine proven safe    1.0   1.000000
# 293                      da homie posted club illusions    0.0   1.000000
# 294                   california measles outbreak grows    0.0   1.000000
# 295   rtuser parents doctors politici stop measles w...    1.0   0.666667
# 296   refuse vaccinate kid think increases risk deve...    1.0   1.000000
# 349   aids n children hiv often lack measles immunit...    0.0   0.666667
# 350   mississippi west virginia two states dont allo...   -1.0   0.333333
# 351   people freaking ebola patient coming unmc worr...    1.0   1.000000
# 352   excited mmr bbq today going freaking awesome g...    0.0   1.000000
# 353   political support crucial reach fifth child va...    0.0   0.666667
# 354   live world people dont vaccinate kids amp seri...    1.0   1.000000
# 355   aids n many cooks might elusive secret ingredi...    1.0   0.666667
# 356   think disneyland started newlyvaccinated worke...   -1.0   0.333333
# 357                             vaccinate freaking kids    1.0   1.000000
# 358   ridiculous even let kids school dont want expo...    1.0   0.666667
# 359   timely ny health dept measles patient boarded ...    0.0   0.666667
# 360    stop blaming first now diseasesbrought ancestors    1.0   0.666667
# 361                       vaccinate child unless doctor   -1.0   0.666667
# 362   children wo lifesaving vaccines pls change amp...    1.0   1.000000
# 363   know youre s kid vaccinations mandatory nobody...    1.0   1.000000
# 364                                             amazing    0.0   1.000000
# 365   pants fire rush blames outbreak children stupi...    1.0   0.666667
# 366   mother kids autism believe vaccines nothing th...    1.0   1.000000
# 367   disney tie hides biggest measles risk adults c...    0.0   1.000000
# 368   whenever encounter antivaccination person list...    1.0   1.000000
# 369   dallas legislator wants reduce vaccine exempti...    0.0   1.000000
# 370                                      better measles    0.0   0.666667
# 371   tougher vaccination rules greet parents backto...    1.0   0.666667
# 372   pretty sure headline parents taking unvaccinat...    1.0   1.000000
# 373                            vaccinated baby hot yoga    1.0   0.666667
# 374               baby doesnt vaccinated neither yorkie    1.0   1.000000
# 375   measles vaccine doesnt increase risk autism ac...    1.0   0.666667
# 376   ended dead within hours vaccinated regardless ...   -1.0   1.000000
# 377                                       vaccine truth    0.0   0.666667
# 378   sadly id much rather child grow autism risk ch...    1.0   1.000000
# 379           measles outbreak makes way ventura county    0.0   0.666667
# 380                            moms love measles effect    0.0   0.666667
# 381          poison ivy vaccines id pay good money shit    1.0   0.666667
# 382   another milestone first set immunizationsbaby ...    1.0   1.000000
# 383   rt attn america giving vaccine prevents cancer...    1.0   0.666667
# 384   talk selfish stupidity cant believe one fraudu...    1.0   1.000000
# 385                   theres way parents vaccinate kids    1.0   0.666667
# 386   interesting know measles outbreak started ille...    1.0   0.666667
# 387         law order svu s e case measles aired living    0.0   1.000000
# 388   everything carries risk benefit comes higher f...    1.0   1.000000
# 389                                kids vaccinated grow    1.0   1.000000
# 390      major finding reduce risk strokes children via    1.0   1.000000
# 391   measles case confirmed oakland county vaccinat...    0.0   0.666667
# 392   child visiting marthas vineyard diagnosed meas...    0.0   1.000000
# 393   im asking bring awareness hpv vaccine usually ...    1.0   0.666667
# 394                       mango pain vaccines poor baby    0.0   0.666667
# 395                   version s link bio somage studios    0.0   1.000000
# 396   letting nixon hook massive criminality granted...    0.0   1.000000
# 397              lets send measles isis via illegals us    0.0   1.000000
# 398   vaccinations mandatory safety kid definitely s...    1.0   1.000000
# 399   heres proof mmr measles vaccine insert says ca...   -1.0   1.000000
# 9939  health officials vaccine winters flu season ma...    0.0   1.000000
# 9940  average people complain live longer releasing ...    0.0   1.000000
# 9941  go herbert lehman high school tomorrow vaccine...    1.0   1.000000
# 9942  average people complain live longer releasing ...    0.0   1.000000
# 9943                   playing mmrbque might propose im    0.0   1.000000
# 9944  kendyl wont allowed school monday dont take wr...   -1.0   0.666667
# 9945  gardasil vaccine victims deaths kno whats impo...   -1.0   0.666667
# 9946  cometh hour rt dr ben carson backs vaccination...    1.0   1.000000
# 9947  silvito el libre measles hit roads usa measles...    0.0   1.000000
# 9948  read measles parties u kidding chicken pox edu...    0.0   0.666667
# 9949  elb measles hit roads usa measles making stron...    0.0   1.000000
# 9950                   measles thing freaks politicians    1.0   0.666667
# 9951  new years wish jenny mccarthy measles mumps ru...    1.0   1.000000
# 9952         need disneyland now give measles dont care    0.0   1.000000
# 9953  health officials international traveler measle...    0.0   1.000000
# 9954               sb passed public health vaccinations    1.0   0.666667
# 9955  dr fauci vaccines responsibility society espec...    1.0   1.000000
# 9956        another study finds link mmr vaccine autism    1.0   1.000000
# 9957                              dear parents lied via    1.0   0.666667
# 9958  listened mmr minutes b realized xpns worst son...    0.0   0.666667
# 9959  warning baby measles public places prompting w...    0.0   0.666667
# 9960  rewarding conversation re amp policies wsamant...    0.0   0.666667
# 9961  especially amount vaccines google uncle tungst...    0.0   0.666667
# 9962      really rt experts measles vaccine link autism    1.0   1.000000
# 9963  measles replace ebola health threat west afric...    1.0   0.666667
# 9964  talk adult man getting basic vaccinations bigg...    1.0   1.000000
# 9965              news vaccines still dont cause autism    1.0   1.000000
# 9966  thank fighting chip childrens health insurance...    1.0   0.666667
# 9967                             give measles ask feels    0.0   0.666667
# 9968  california measles cases tied disney outbreak ...    0.0   1.000000
# 9969  meningitis vaccine offered weho mans death ste...    0.0   0.666667
# 9970               measles cases hit year high cdc says    1.0   0.666667
# 9971                             calls angel mmrj sound    0.0   1.000000
# 9972  free backtoschool events popular weekend need ...    1.0   1.000000
# 9973  children go school without proper vaccinations...   -1.0   0.333333
# 9974                                measles tho tf come    0.0   1.000000
# 9975  mmr hr delay tues cares opening am yr old clas...    0.0   1.000000
# 9976  begin largescale testing ebola vaccine guinea ...    0.0   0.666667
# 9977  kfiam gov brown signs california bill imposing...    0.0   0.666667
# 9978                         im sneezing better measles    0.0   1.000000
# 9979  msnbc bastardsyou got headline read beck sees ...    1.0   0.666667
# 9980  several disneyland employees diagnosed measles...    0.0   0.666667
# 9981             amazing diseases gone vaccines oh wait    1.0   1.000000
# 9982                rare measles didnt u vaccine u baby    0.0   0.666667
# 9983              least measles cases linked visits dec    0.0   1.000000
# 9984  unfortunately national weather service forgot ...    1.0   1.000000
# 9985                     mmr vip pre sale sold got mine    0.0   1.000000
# 9986              immunization child hoag health center    1.0   1.000000
# 9987  getting flu wooping cough vaccine tomorrow sur...    1.0   1.000000
# 9988  thought vaccinating children something amp chi...    1.0   1.000000
# 9989  stop worrying theyll lose vaccinations missing...    1.0   1.000000
# 9990                        dawg said gone rich one day    0.0   1.000000
# 9991                                  one half hour isa    0.0   1.000000
# 9992  doesnt want vaccinate kids call fucking retard...    1.0   0.666667
# 9993  ill say glad mom gave mmr vaccination little r...    1.0   1.000000
# 9994  living time sperm used waste jenny mccarthy be...    1.0   1.000000
# 9995  spite measles outbreaks judge mi threatens put...    1.0   0.666667
# 9996  interesting trends child immunization oklahoma...    0.0   1.000000
# 9997  cdc says measles highest levels decades return...    0.0   1.000000
# 9998  pneumonia vaccine women w risk pulmonary disea...    1.0   0.666667

# %%
#Ensuring there are no null values

data.isna().sum()
# Out:
# safe_tweet    0
# label         0
# agreement     0
# dtype: int64

# %%
# Change tweet rows to tuples  to conform to the standard

data['safe_tweet'] = data['safe_tweet'].apply(lambda tweet: tuple(tweet.split(),))

# %%
data.head()
# Out:
#                                           safe_tweet  label  agreement
# 0            (amp, big, homie, meanboy, stegman, st)    0.0        1.0
# 1  (im, thinking, devoting, career, proving, auti...    1.0        1.0
# 2                       (vaccines, vaccinate, child)   -1.0        1.0
# 3  (mean, immunize, kid, something, wont, secretl...   -1.0        1.0
# 4  (thanks, catch, performing, la, nuit, nyc, st,...    0.0        1.0

# %% [markdown]
# **Data Splitting**

# %%
train, eval= train_test_split(data, test_size= 0.2, stratify= data["label"], random_state= 42)

# %%
train.head()
# Out:
#                                              safe_tweet  label  agreement
# 8627      (vaccine, safety, side, effects, kids, found)   -1.0   0.333333
# 6394  (dude, gotten, vaccinated, swag, virus, known,...    1.0   1.000000
# 8636  (vaccine, horrors, medical, mutilation, childr...   -1.0   1.000000
# 323                (mighty, mmr, music, money, records)    0.0   1.000000
# 3254  (average, people, complain, live, longer, rele...    0.0   1.000000

# %%
eval.head()
# Out:
#                                              safe_tweet  label  agreement
# 8474  (bet, asked, cool, bandaids, group, health, an...    1.0   0.666667
# 5486  (vaccination, contain, hg, mercury, non, chemi...   -1.0   0.666667
# 9863  (amen, rt, good, thing, parents, dont, vaccina...    1.0   1.000000
# 6977  (never, understand, weird, state, mind, cause,...    1.0   1.000000
# 7866   (manditory, cootie, vaccinations, protect, kids)    1.0   0.666667

# %%
print(f"new dataframe shapes: train is {train.shape}, eval is {eval.shape}")
# Out:
# new dataframe shapes: train is (7976, 3), eval is (1994, 3)

# %%
#saving the train and eval data to csv
train.to_csv("/content/train.csv")
eval.to_csv("/content/eval.csv")

# %% [markdown]
# **Load the Dataset**

# %%
dataset= load_dataset( "csv", data_files= { "train":"train.csv", "eval":"eval.csv"}                     )
# Out:
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating eval split: 0 examples [00:00, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'safe_tweet', 'label', 'agreement'],
#         num_rows: 7976
#     })
#     eval: Dataset({
#         features: ['Unnamed: 0', 'safe_tweet', 'label', 'agreement'],
#         num_rows: 1994
#     })
# })

# %% [markdown]
#  **Tokenization**

# %%
distil= "distilbert-base-uncased"

# %%
#create an instance for tokenizer
distil_tokenizer= AutoTokenizer.from_pretrained(distil)

# %%
data["safe_tweet"].head()
# Out:
# 0              (amp, big, homie, meanboy, stegman, st)
# 1    (im, thinking, devoting, career, proving, auti...
# 2                         (vaccines, vaccinate, child)
# 3    (mean, immunize, kid, something, wont, secretl...
# 4    (thanks, catch, performing, la, nuit, nyc, st,...
# Name: safe_tweet, dtype: object

# %% [markdown]
# ## Preprocessing Data

# %%
## changing labels to 0,1,2  from the initial labels -1, 0, 1

def transform_labels(input):
  label= input["label"]
  num =0

  if label== -1:
    num= 0
  elif label== 0:
    num =1
  elif label == 1:
    num = 2
  return {"label": num}

def distil_tokenize(example):
  return distil_tokenizer(example["safe_tweet"], padding= "max_length", truncation=True)

# %%
## Converting tweets to tokens for the model to work with and eliminating features that are not needed for the analysis

dataset= dataset.map(distil_tokenize, batched= True)
remove_columns= ['Unnamed: 0', 'safe_tweet', 'label', 'agreement']
dataset = dataset.map(transform_labels, remove_columns=remove_columns)
# Out:
# Map:   0%|          | 0/7976 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1994 [00:00<?, ? examples/s]
# Map:   0%|          | 0/7976 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1994 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 7976
#     })
#     eval: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 1994
#     })
# })

# %% [markdown]
# **Handling  Class Imbalance**
#
# From the EDA, we realized there was an imbalance with -1 class (now the 0 class) and it will be dealt with

# %%
class_weights= (1-(data["label"].value_counts().sort_index() /len(data))).values
class_weights
# Out:
# array([0.89618857, 0.50992979, 0.59388164])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
##uploading weights to the GPU


class_weights= torch.from_numpy(class_weights).float().to(device)

# %%
##pyTorch recognizes our label column to be named as 'labels' therefore, I am going to go ahead and rename it

dataset= dataset.rename_column("label","labels")

# %%
model= AutoModelForSequenceClassification.from_pretrained(distil, num_labels= 3)
# Out:
# Downloading model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'classifier.weight', 'pre_classifier.bias', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### 1.Finetuning DistilBert with Class Weight

# %%
##creating an instance for the model
model= AutoModelForSequenceClassification.from_pretrained(distil, num_labels= 3)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.weight', 'classifier.weight', 'pre_classifier.bias', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
##creating a custom class to enable the classweight


class WeightedLossTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False):
        labels = inputs["labels"]
        inputs.pop("labels")
        outputs = model(**inputs)
        logits = outputs.logits.float()
        labels = labels.long()
        loss_func = nn.CrossEntropyLoss(weight=class_weights)
        loss = loss_func(logits, labels)
        return (loss, outputs) if return_outputs else loss

# %%
#f1-score will be used because there is class imbalance in the dataset

def compute_metrics(pred):
  labels = pred.label_ids
  preds = pred.predictions.argmax(-1)
  f1 = f1_score(labels, preds, average="weighted")
  return {"f1": f1}

# %%
model_name = f"{distil}-Distilbert-Model"

# %%
#setting batch size to 16
batch_size= 16

# %%
#creating an instance for the training arguments

training_args = TrainingArguments( output_dir=model_name,
   num_train_epochs=10, load_best_model_at_end=True,evaluation_strategy="steps",save_strategy="steps",push_to_hub=True

)
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %%
##setting a shuffle seed to avoid randomization at each rerun
train_dataset= dataset['train'].shuffle(seed=10)
eval_dataset= dataset['eval'].shuffle(seed=10)

# %%
#making a connection to huggingface
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
#loading training arguments

trainer = WeightedLossTrainer(
      model= model,
      args= training_args,
      train_dataset= train_dataset,
      eval_dataset= eval_dataset,
      tokenizer= distil_tokenizer,
      compute_metrics=compute_metrics )

# %%
##training the model

trainer.train()
# Out:
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value